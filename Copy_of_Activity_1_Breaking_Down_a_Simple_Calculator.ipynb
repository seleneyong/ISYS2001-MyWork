# %% [markdown]
# <a href="https://colab.research.google.com/github/seleneyong/ISYS2001-MyWork/blob/main/Copy_of_Activity_1_Breaking_Down_a_Simple_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this worksheet we will take a simple calculator programme and break it into smaller, manageable parts. Rather than working with one long "wall of code", we will split it into clear steps. This lets you focus on one task at a time and makes the whole problem much easier to reason about.
#
# This is a guided walkthrough. It shows you how to decompose a problem and implement each part as a function, and how to work alongside an AI assistant while keeping your own understanding of what the code does.
#
# **By the end of this worksheet you should be able to:**
#
# - break a problem into smaller, self-contained functions
# - apply basic modular design to organise your code
# - use AI to analyse a problem while still understanding the result yourself
# - carry these habits into the finance mini-project later this week
#
# # The original "wall of code"
#
# Below is a basic calculator that does everything at once. It shows a menu, reads the user's input, performs a calculation, and prints the result. Run it if you would like to confirm it works before we take it apart.

# %%
# Define the calculator functions
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b

# Display the menu
print("Simple Calculator Menu")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

# Get the user's choice
choice = input("Enter your choice (1-4): ")

# Get the two numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Perform the chosen operation
if choice == "1":
    result = add(num1, num2)
elif choice == "2":
    result = subtract(num1, num2)
elif choice == "3":
    result = multiply(num1, num2)
elif choice == "4":
    result = divide(num1, num2)
else:
    result = "Invalid choice."

# Display the result
print("Result:", result)
# Out:
# Simple Calculator Menu
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter your choice (1-4): 2
# Enter the first number: 2
# Enter the second number: 3
# Result: -1.0

# %% [markdown]
# # Analysing the problem with AI
#
# Before we break the calculator down by hand, it is worth seeing how an AI assistant can help you understand the structure of code you have been given.
#
# ## Your first AI collaboration
#
# Copy the "wall of code" above and give an AI assistant a prompt along these lines:
#
# ```
# I have a calculator programme that does everything in one block. Help me
# identify the main tasks it performs and suggest how to break it into
# separate, reusable functions.
#
# Here is my code: [paste the calculator code here]
#
# Please explain:
# 1. What are the main tasks this programme performs?
# 2. How would you group these into separate functions?
# 3. What are the benefits of this modular approach?
# ```
#
# Notice how specific that prompt is. In your earlier labs, the students who got the most out of AI were the ones who wrote detailed prompts that named the features and structure they wanted, rather than asking it to "build me an app". Keep doing that here.
#
# **As you read the response, ask yourself:**
#
# - How did the AI's analysis compare to your own first reading of the code?
# - Did it point out anything you had missed?
#
# ## Breaking the problem down by hand
#
# Whether you used AI or worked it out yourself, the code above is hard to follow because it does several things at once. We can describe it as five steps:
#
# 1. **Display the menu:** show the calculator options.
# 2. **Get the user's choice:** ask which operation to perform.
# 3. **Get the numbers:** ask the user for two numbers.
# 4. **Perform the calculation:** apply the chosen operation.
# 5. **Display the result:** show the result to the user.
#
# Splitting the problem this way lets us work on one part at a time. Compare this breakdown with whatever the AI suggested, and note where they agree and differ.
#
# # Building a modular design, step by step
#
# Now we will implement each step as its own function. We will start with the menu, then getting a number, then performing the calculation.
#
# ## Step 1: a function to display the menu
#
# First, a function that displays the menu and returns the user's choice.
#
# Before writing it, you might ask an AI for a structure to work from. A worked example of a good prompt:
#
# ```
# Help me create a function called get_operation() that:
# - displays a menu with four options (Add, Subtract, Multiply, Divide)
# - reads the user's choice
# - returns the choice
#
# I want to understand each step, so please:
# 1. show me the function structure first
# 2. explain why we return the value instead of printing it
# 3. suggest any improvements to the user experience
#
# Only use basic Python (print, input, return).
# ```
#
# **Pseudo-code:**
#
# ```
# function get_operation():
#     Display "Simple Calculator Menu"
#     Display "1. Add"
#     Display "2. Subtract"
#     Display "3. Multiply"
#     Display "4. Divide"
#     Prompt user for choice
#     Return the user's choice
# ```
#
# **Code:**
#
# ```python
# def get_operation():
#     print("Simple Calculator Menu")
#     print("1. Add")
#     print("2. Subtract")
#     print("3. Multiply")
#     print("4. Divide")
#     choice = input("Enter your choice (1-4): ")
#     return choice
# ```
#
# Check your understanding: why is it better for this function to return the choice rather than print it? If you are not sure, ask the AI to explain the difference, then put the answer in your own words.
#
# ## Step 2: a function to get a number
#
# Next, a function that reads a number from the user. Try prompting the AI with a clear set of constraints:
#
# ```
# Help me write a function called get_number() that:
# - takes a prompt message as a parameter
# - reads a number from the user
# - converts it to a float and returns it
#
# Constraints:
# - only use basic Python: input(), float(), return
# - explain why we pass the prompt in as a parameter instead of hard-coding it
# - explain what happens if the user types text instead of a number
#
# I want to understand the logic, not just get working code.
# ```
#
# **Pseudo-code:**
#
# ```
# function get_number(prompt):
#     Ask the user for a number using the given prompt
#     Convert the input to a float
#     Return the number
# ```
#
# **Code:**
#
# ```python
# def get_number(prompt):
#     return float(input(prompt))
# ```
#
# **Test your understanding:**
#
# 1. Why do we pass `prompt` in as a parameter instead of hard-coding the message?
# 2. What happens if the user enters "abc" instead of a number?
# 3. How does passing the prompt in make this function more reusable?
#
# We will come back to that second question in Activity 2, where you will make this function cope with bad input.
#
# ## Step 3: a function to perform the calculation
#
# This function takes the chosen operation and two numbers, and returns the correct result. It is a good example of a decision structure that coordinates the other functions.
#
# ```
# I need a function that takes an operation choice (1-4) and two numbers,
# then performs the matching calculation:
# - if choice is "1": call add(num1, num2)
# - if choice is "2": call subtract(num1, num2), and so on
#
# Help me understand:
# 1. what kind of structure this is (a decision structure)
# 2. why this is clearer than one large function containing every calculation
# 3. how this function works together with the others we have written
# ```
#
# **Pseudo-code:**
#
# ```
# function perform_calculation(operation, num1, num2):
#     if operation is "1":
#         return add(num1, num2)
#     else if operation is "2":
#         return subtract(num1, num2)
#     else if operation is "3":
#         return multiply(num1, num2)
#     else if operation is "4":
#         return divide(num1, num2)
#     else:
#         return "Invalid choice."
# ```
#
# **Code:**
#
# ```python
# def perform_calculation(operation, num1, num2):
#     if operation == "1":
#         return add(num1, num2)
#     elif operation == "2":
#         return subtract(num1, num2)
#     elif operation == "3":
#         return multiply(num1, num2)
#     elif operation == "4":
#         return divide(num1, num2)
#     else:
#         return "Invalid choice."
# ```
#
# **Think about this:**
#
# - This function acts as a coordinator between the user's input and the calculation functions. What would you need to change to add a new operation?
# - How does keeping these parts separate make problems easier to track down?
#
# ## Step 4: a simple safeguard in the divide function
#
# We have not covered error handling in depth yet, but we can add a small check to `divide()` to avoid dividing by zero, which would otherwise stop the programme. We will look at error handling properly later in the semester.
#
# **Pseudo-code:**
#
# ```
# function divide(a, b):
#     if b equals 0:
#         return "Error: Cannot divide by zero."
#     else:
#         return a divided by b
# ```
#
# **Code:**
#
# ```python
# def divide(a, b):
#     if b == 0:
#         return "Error: Cannot divide by zero."
#     else:
#         return a / b
# ```
#
# # The final modular code
#
# Now we put the functions together in one script. Notice that most of the functions return values rather than printing them. The menu function is the exception, since its job is to display options. Returning values keeps the functions flexible and reusable. Run the code below to confirm it works.

# %%
# Define the calculator functions
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error: Cannot divide by zero."
    else:
        return a / b

# Function to display the menu and get the user's choice
def get_operation():
    print("Simple Calculator Menu")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    choice = input("Enter your choice (1-4): ")
    return choice

# Function to get a floating-point number from the user
def get_number(prompt):
    return float(input(prompt))

# Function to perform the calculation based on the operation
def perform_calculation(operation, num1, num2):
    if operation == "1":
        return add(num1, num2)
    elif operation == "2":
        return subtract(num1, num2)
    elif operation == "3":
        return multiply(num1, num2)
    elif operation == "4":
        return divide(num1, num2)
    else:
        return "Invalid choice."

# Main script
operation = get_operation()
num1 = get_number("Enter the first number: ")
num2 = get_number("Enter the second number: ")
result = perform_calculation(operation, num1, num2)
print("Result:", result)

# %% [markdown]
# > **A note on terminology.** What we have just done is called refactoring: restructuring existing code, changing how it is organised internally, without changing what it does from the outside. Refactoring improves things like readability and complexity, which makes code easier to maintain and extend. The term will become more useful as you work with larger programmes and with AI-generated code.
#
# # Working effectively with AI
#
# A few principles you can take from this worksheet:
#
# **Before you start**
#
# - Try to understand the problem yourself first, then use AI to check or extend your thinking.
# - Be specific. Name the features and the structure you want, as you did in earlier labs. A detailed prompt gives you a far more useful answer than "build me a calculator".
# - Ask for explanations, not just working code.
#
# **While you work**
#
# - Break a large request into smaller steps.
# - Check that you can explain any code the AI gives you in your own words.
# - Change the code slightly and predict what will happen, to test whether you actually understand it.
#
# **After you finish**
#
# - Compare the AI's approach with your own.
# - Notice the patterns it used, so you recognise them next time.
#
# # Checking your understanding
#
# Work through these on your own, then use AI to check your answers if you are unsure.
#
# **Function design**
#
# 1. Why does each calculation function return a value instead of printing it directly?
# 2. What makes a function reusable, and why does that matter?
# 3. How do parameters make a function more flexible?
#
# **How the parts fit together**
#
# 1. How do the functions work together to produce a working calculator?
# 2. What would you change to add a new operation, such as modulus or exponent?
# 3. Which function would you change to improve how the calculator handles bad input?
#
# # Optional challenges
#
# **Challenge 1: add a modulus operation.** Add a `modulus(a, b)` function that returns the remainder, add option 5 to the menu, and update `perform_calculation()`. A prompt you might use:
#
# ```
# Help me add a modulus operation to my calculator. I need to:
# 1. write a modulus function that returns the remainder
# 2. add option 5 to the menu
# 3. add the matching case to perform_calculation()
#
# Explain each step, and why the modular design makes adding a feature easier.
# ```
#
# **Challenge 2: think ahead about bad input.** Ask an AI how you might stop `get_number()` from failing when the user types text instead of a number, and ask it to show two or three different approaches with the trade-offs of each. You will build on this in Activity 2.
#
# # Where this leads
#
# The modular habits you have practised here carry straight into the rest of the week and the unit:
#
# - **This week's mini-project:** you will build a small set of finance functions (categorising expenses, budget calculations, and so on) using the same approach.
# - **Assessment 2:** your programming project will lean heavily on being able to break a problem into clear functions.
#
# Being able to direct an AI assistant, then read and check what it produces, is a core skill for an information systems graduate. You are not being trained to write every line unaided; you are being trained to understand a problem, describe it precisely, and judge whether the solution is any good.
#
# # Reflection
#
# This worksheet is practice. You do not submit it on its own. It prepares you for this week's lab exit ticket, which is the finance mini-project. Keep your notes, since you may be asked to talk through your reasoning.
#
# For your own learning, write a short reflection (around 200 to 300 words) on:
#
# 1. **Modular design:** how did breaking the calculator into functions change the way you saw the problem?
# 2. **Working with AI:** which prompting habits worked best for you? Were your prompts specific enough?
# 3. **Understanding:** did comparing the AI's suggestions with your own version help? How?
# 4. **Next steps:** how will you apply modular design to the mini-project?
#
# You have finished this worksheet if you can explain how each function contributes to the calculator, describe why modular design is easier to work with than one long block, and use AI to help without losing track of what the code does.
#
# Next, in Activity 2, you will make this calculator stand up to bad input using the validation techniques you met in Week 4.
